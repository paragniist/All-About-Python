# %%
import pandas as pd

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Salary': [50000, 60000, 70000]
}

df = pd.DataFrame(data)
df['marks']=[70, 0,0]
sorted_df=df.sort_values(by='marks', ascending=True)
print(sorted_df)
# Out:
#       Name  Age  Salary  marks
# 1      Bob   30   60000      0
# 2  Charlie   35   70000      0
# 0    Alice   25   50000     70

# %%
df['Experience'] = [5,4,1]

# %%
print(df)
# Out:
#       Name  Age  Salary  marks  Experience
# 0    Alice   25   50000     70           5
# 1      Bob   30   60000      0           4
# 2  Charlie   35   70000      0           1

# %%
df = pd.read_csv('customers.csv')
df.head(5)
df.describe()
# df.dtypes
df.isnull()
df_filled = df.fillna("Google")
df_filled.head()
# Out:
#    Index      Customer Id First Name Last Name                   Company  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter           Rasmussen Group
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano               Vega-Gentry
# 2      3  6F94879bDAfE5a6        Roy     Berry             Murillo-Perry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen                    Google
# 4      5  053d585Ab6b3159     Joanna    Bender  Martin, Lang and Andrade
#
#                 City                     Country                 Phone 1  \
# 0       East Leonard                       Chile            229.077.5154
# 1  East Jimmychester                    Djibouti              5153435776
# 2      Isabelborough         Antigua and Barbuda         +1-539-402-0259
# 3         Bensonview          Dominican Republic  001-808-617-6467x12895
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
#
#                  Phone 2                        Email Subscription Date  \
# ...

# %% [markdown]
# Filling missing values with mean of the data

# %%
# df.head(5)
grouped_df=df.groupby('City').sum()
print(grouped_df)
# Out:
#                   Index      Customer Id First Name    Last Name  \
# City
# Acevedoville         29  3B5dAAFA41AFa22   Stefanie  Fitzpatrick
# Bensonview            4  5Cef8BFA16c5e3c      Linda        Olsen
# Brittanyview         23  2FB0FAA1d429421    Colleen       Howard
# Bryanville           25  eC1927Ca84E033e      Shane       Wilcox
# Burchbury            15  6fEaA1b7cab7B6C      Faith         Lutz
# ...                 ...              ...        ...          ...
# West Marthaburgh     35  aA9BAFfBc3710fe      Faith         Moon
# West Priscilla        5  053d585Ab6b3159     Joanna       Bender
# West Reginald        77  BF6a1f9bd1bf8DE   Brittany       Zuniga
# West Samuel          31  64DCcDFaB9DFd4e       Jack         Tate
# Zimmermanland        47  300A40d3ce24bBA   Geoffrey       Guzman
#
#                                       Company  \
# City
# Acevedoville                    Santana-Duran
# Bensonview                                  0
# ...

# %% [markdown]
# <h4>READING DATA FROM DIFFERENT SOURCES USING PANDAS

# %%
# %pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
url = "https://www.fdic.gov/bank-failures/failed-bank-list"
df = pd.read_html(url)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~/Desktop/Python DS/venv/lib/python3.12/urllib/request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File ~/Desktop/Python DS/venv/lib/python3.12/http/client.py:1319, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1318 """Send a complete request to the server."""
# -> 1319 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/Desktop/Python DS/venv/lib/python3.12/http/client.py:1365, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1364     body = _encode(body, 'body')
# ...

# %%
df[0]
# Out:
#                                Bank Name               City         State  \
# 0                   Pulaski Savings Bank            Chicago      Illinois
# 1     The First National Bank of Lindsay            Lindsay      Oklahoma
# 2  Republic First Bank dba Republic Bank       Philadelphia  Pennsylvania
# 3                          Citizens Bank           Sac City          Iowa
# 4               Heartland Tri-State Bank            Elkhart        Kansas
# 5                    First Republic Bank      San Francisco    California
# 6                         Signature Bank           New York      New York
# 7                    Silicon Valley Bank        Santa Clara    California
# 8                      Almena State Bank             Almena        Kansas
# 9             First City Bank of Florida  Fort Walton Beach       Florida
#
#     Cert                Acquiring Institution      Closing Date  \
# 0  28611                      Millennium Bank  January 17, 2025
# ...

# %% [markdown]
# <h4> EXAMPLE : importing mobile country codes from wikipedia page using pandas

# %%
url = "https://en.wikipedia.org/wiki/Mobile_country_code"
df = pd.read_html(url)

# %%
df[1]
# Out:
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
# ...

# %%
df_excel = pd.read_csv('customers.csv')
df_excel.head(5)
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %% [markdown]
# <h4> Creating and Converting Excel/ csv file into PICKLE file

# %%
df_excel.to_pickle('df_excel')

# %%
pd.read_pickle('df_excel')
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...
